# %%
# List available plot styles
plt.style.available
# Out:
# [u'seaborn-darkgrid',
#  u'seaborn-notebook',
#  u'classic',
#  u'seaborn-ticks',
#  u'grayscale',
#  u'bmh',
#  u'seaborn-talk',
#  u'dark_background',
#  u'ggplot',
#  u'fivethirtyeight',
#  u'_classic_test',
#  u'seaborn-colorblind',
#  u'seaborn-deep',
#  u'seaborn-whitegrid',
#  u'seaborn-bright',
#  u'seaborn-poster',
#  u'seaborn-muted',
#  u'seaborn-paper',
#  u'seaborn-white',
#  u'seaborn-pastel',
#  u'seaborn-dark',
#  u'seaborn',
#  u'seaborn-dark-palette']

# %%
import numpy as np
from scipy import special as sp
import matplotlib.pyplot as plt

plt.style.use('seaborn-paper')
plt.style.use('seaborn-dark-palette')
# %matplotlib inline

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (10, 7)
plt.rcParams['font.size'] = 65

x = np.linspace(0, 25, 100)
for n in range(4):
    y = sp.jn(n, x)
    plt.plot(x, y, label=r'$J_%s(x)$' % n)

plt.axis([0, 20, -.6, 1.05]) 
plt.axhline(0, color='green', label='_nolegend_')
plt.grid()
plt.legend(fontsize=24)
plt.legend(frameon=False)
plt.xlabel('$x$')
plt.title(r'Bessel Functions $J_n(x)$', fontsize=28);
plt.ticklabel_format(useOffset=False)
